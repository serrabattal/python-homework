# %%
# initial imports for first dataset (whale_returns)
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline
# Take sample of data

whale_path = Path("C:\whale_returns.csv")
whale_returns = pd.read_csv(whale_path, index_col="Date")
whale_returns.sample(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2016-08-05                   0.008333            0.000485
# 2018-02-21                  -0.005056           -0.005319
# 2018-09-17                  -0.007657           -0.006064
# 2016-06-08                   0.000461           -0.000279
# 2016-05-04                  -0.007072           -0.009152
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2016-08-05                     0.029448                0.022421
# 2018-02-21                    -0.012825                0.000735
# 2018-09-17                    -0.008787               -0.021380
# 2016-06-08                     0.004087               -0.014419
# 2016-05-04                     0.009203               -0.008969

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path
# %matplotlib inline


print("--------------------------")

# Set the file path
whale_path = Path("C:\whale_returns.csv")

# Read in the CSV as a DataFrame
whale_returns = pd.read_csv(whale_path)
whale_returns.head()
# Out:
# --------------------------
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  2015-03-02                        NaN                 NaN
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
# 4  2015-03-06                  -0.007905           -0.003574
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098

# %%
# Identify Series count
whale_returns.count()
# Out:
# Date                           1060
# SOROS FUND MANAGEMENT LLC      1059
# PAULSON & CO.INC.              1059
# TIGER GLOBAL MANAGEMENT LLC    1059
# BERKSHIRE HATHAWAY INC         1059
# dtype: int64

# %%
# Determine number of nulls
whale_returns.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Cleanse nulls from DataFrame by filling na
whale_returns["SOROS FUND MANAGEMENT LLC"] = whale_returns["SOROS FUND MANAGEMENT LLC"].fillna("Unknown")
whale_returns
# Out:
#             Date SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     2015-03-02                   Unknown                 NaN
# 1     2015-03-03               -0.00126551           -0.004981
# 2     2015-03-04                0.00222991            0.003241
# 3     2015-03-05                  0.004016            0.004076
# 4     2015-03-06               -0.00790536           -0.003574
# ...          ...                       ...                 ...
# 1055  2019-04-25              -0.000284876           -0.001291
# 1056  2019-04-26                0.00814945            0.009162
# 1057  2019-04-29                0.00125435            0.002719
# 1058  2019-04-30               -0.00129452           -0.002211
# 1059  2019-05-01               -0.00584705           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                             NaN                     NaN
# 1                       -0.000496               -0.006569
# 2                       -0.002534                0.004213
# 3                        0.002355                0.006726
# 4                       -0.008481               -0.013098
# ...                           ...                     ...
# 1055                    -0.005153                0.004848
# 1056                     0.012355                0.010434
# 1057                     0.006251                0.005223
# 1058                    -0.000259               -0.003702
# 1059                    -0.007936               -0.007833
#
# [1060 rows x 5 columns]

# %%
whale_returns = whale_returns.dropna().copy()
whale_returns
# Out:
#             Date SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1     2015-03-03               -0.00126551           -0.004981
# 2     2015-03-04                0.00222991            0.003241
# 3     2015-03-05                  0.004016            0.004076
# 4     2015-03-06               -0.00790536           -0.003574
# 5     2015-03-09                0.00058228            0.004225
# ...          ...                       ...                 ...
# 1055  2019-04-25              -0.000284876           -0.001291
# 1056  2019-04-26                0.00814945            0.009162
# 1057  2019-04-29                0.00125435            0.002719
# 1058  2019-04-30               -0.00129452           -0.002211
# 1059  2019-05-01               -0.00584705           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                       -0.000496               -0.006569
# 2                       -0.002534                0.004213
# 3                        0.002355                0.006726
# 4                       -0.008481               -0.013098
# 5                        0.005843               -0.001652
# ...                           ...                     ...
# 1055                    -0.005153                0.004848
# 1056                     0.012355                0.010434
# 1057                     0.006251                0.005223
# 1058                    -0.000259               -0.003702
# 1059                    -0.007936               -0.007833
#
# [1059 rows x 5 columns]

# %%
whale_returns.isnull().sum()
# Check duplicates
whale_returns.duplicated()
# Out:
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 1055    False
# 1056    False
# 1057    False
# 1058    False
# 1059    False
# Length: 1059, dtype: bool

# %%
# Identify if numeric field with $ symbol
whale_returns.head()
# Out:
#          Date SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1  2015-03-03               -0.00126551           -0.004981
# 2  2015-03-04                0.00222991            0.003241
# 3  2015-03-05                  0.004016            0.004076
# 4  2015-03-06               -0.00790536           -0.003574
# 5  2015-03-09                0.00058228            0.004225
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098
# 5                     0.005843               -0.001652

# %%
# Convert `soros` from `object` to `float`
whale_returns["SOROS FUND MANAGEMENT LLC"] = whale_returns["SOROS FUND MANAGEMENT LLC"].astype("float")

# %%
whale_returns.dtypes
# Out:
# Date                            object
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
# Convert date strings into datetime objects and set the datetime as the index
whale_returns.set_index(pd.to_datetime(whale_returns['Date'], infer_datetime_format=True), inplace=True)
whale_returns.head()
# Out:
#                   Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03  2015-03-03                  -0.001266           -0.004981
# 2015-03-04  2015-03-04                   0.002230            0.003241
# 2015-03-05  2015-03-05                   0.004016            0.004076
# 2015-03-06  2015-03-06                  -0.007905           -0.003574
# 2015-03-09  2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
whale_returns.drop(columns=['Date'], inplace=True)
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
# initial imports for second dataset (algo_returns)

import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline
# Take sample of data

algo_path = Path("C:/algo_returns.csv")
algo_returns = pd.read_csv(algo_path, index_col="Date")
algo_returns.sample(5)
# Out:
#               Algo 1    Algo 2
# Date
# 2018-05-14  0.000915  0.001635
# 2014-09-04 -0.002193 -0.001654
# 2017-10-11 -0.000572  0.001052
# 2019-01-15  0.000369  0.007277
# 2017-11-17  0.001917  0.003595

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path
# %matplotlib inline

print("--------------------------")

# Set the file path
algo_path = Path("C:/algo_returns.csv")

# Read in the CSV as a DataFrame
algo_returns = pd.read_csv(algo_path)
algo_returns.head()
# Out:
# --------------------------
#          Date    Algo 1  Algo 2
# 0  2014-05-28  0.001745     NaN
# 1  2014-05-29  0.003978     NaN
# 2  2014-05-30  0.004464     NaN
# 3  2014-06-02  0.005692     NaN
# 4  2014-06-03  0.005292     NaN

# %%
# Identify Series count
algo_returns.count()
# Out:
# Date      1241
# Algo 1    1241
# Algo 2    1235
# dtype: int64

# %%
# Determine number of nulls
algo_returns.isnull().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Cleanse nulls from DataFrame by filling na
algo_returns["Algo 1"] = algo_returns["Algo 1"].fillna("Unknown")
algo_returns
# Out:
#             Date    Algo 1    Algo 2
# 0     2014-05-28  0.001745       NaN
# 1     2014-05-29  0.003978       NaN
# 2     2014-05-30  0.004464       NaN
# 3     2014-06-02  0.005692       NaN
# 4     2014-06-03  0.005292       NaN
# ...          ...       ...       ...
# 1236  2019-04-25  0.000682 -0.007247
# 1237  2019-04-26  0.002981  0.005256
# 1238  2019-04-29  0.005208  0.002829
# 1239  2019-04-30 -0.002944 -0.001570
# 1240  2019-05-01  0.000094 -0.007358
#
# [1241 rows x 3 columns]

# %%
algo_returns = algo_returns.dropna().copy()
algo_returns
# Out:
#             Date    Algo 1    Algo 2
# 6     2014-06-05  0.004062  0.013285
# 7     2014-06-06  0.001857  0.008284
# 8     2014-06-09 -0.005012  0.005668
# 9     2014-06-10  0.004406 -0.000735
# 10    2014-06-11  0.004760 -0.003761
# ...          ...       ...       ...
# 1236  2019-04-25  0.000682 -0.007247
# 1237  2019-04-26  0.002981  0.005256
# 1238  2019-04-29  0.005208  0.002829
# 1239  2019-04-30 -0.002944 -0.001570
# 1240  2019-05-01  0.000094 -0.007358
#
# [1235 rows x 3 columns]

# %%
algo_returns.dtypes
# Out:
# Date       object
# Algo 1    float64
# Algo 2    float64
# dtype: object

# %%
# Convert date strings into datetime objects and set the datetime as the index
algo_returns.set_index(pd.to_datetime(algo_returns['Date'], infer_datetime_format=True), inplace=True)
algo_returns.head()
# Out:
#                   Date    Algo 1    Algo 2
# Date
# 2014-06-05  2014-06-05  0.004062  0.013285
# 2014-06-06  2014-06-06  0.001857  0.008284
# 2014-06-09  2014-06-09 -0.005012  0.005668
# 2014-06-10  2014-06-10  0.004406 -0.000735
# 2014-06-11  2014-06-11  0.004760 -0.003761

# %%
algo_returns.drop(columns=['Date'], inplace=True)
algo_returns.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %%
# initial imports for third dataset (sp_returns)

import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline
# Take sample of data

sp_path = Path("C:/sp500_history.csv")
sp_returns = pd.read_csv(sp_path, index_col="Date")
sp_returns.sample(5)
# Out:
#               Close
# Date
# 5-Nov-15   $2099.93
# 13-Feb-17  $2328.25
# 11-Feb-14  $1819.75
# 29-Mar-16  $2055.01
# 12-Mar-19  $2791.52

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path
# %matplotlib inline

print("--------------------------")

# Set the file path
sp_path = Path("C:/sp500_history.csv")

# Read in the CSV as a DataFrame
sp_returns = pd.read_csv(sp_path)
sp_returns.head()
# Out:
# --------------------------
#         Date     Close
# 0  23-Apr-19  $2933.68
# 1  22-Apr-19  $2907.97
# 2  18-Apr-19  $2905.03
# 3  17-Apr-19  $2900.45
# 4  16-Apr-19  $2907.06

# %%
# Identify Series count
sp_returns.count()
# Out:
# Date     1649
# Close    1649
# dtype: int64

# %%
# Determine number of nulls
sp_returns.isnull().sum()
# Out:
# Date     0
# Close    0
# dtype: int64

# %%
# Cleanse nulls from DataFrame by filling na
sp_returns["Close"] = sp_returns["Close"].fillna("Unknown")
sp_returns
# Out:
#            Date     Close
# 0     23-Apr-19  $2933.68
# 1     22-Apr-19  $2907.97
# 2     18-Apr-19  $2905.03
# 3     17-Apr-19  $2900.45
# 4     16-Apr-19  $2907.06
# ...         ...       ...
# 1644   5-Oct-12  $1460.93
# 1645   4-Oct-12  $1461.40
# 1646   3-Oct-12  $1450.99
# 1647   2-Oct-12  $1445.75
# 1648   1-Oct-12  $1444.49
#
# [1649 rows x 2 columns]

# %%
# Convert date strings into datetime objects and set the datetime as the index
sp_returns.set_index(pd.to_datetime(sp_returns["Date"], infer_datetime_format=True), inplace=True)
sp_returns.head()
# Out:
#                  Date     Close
# Date
# 2019-04-23  23-Apr-19  $2933.68
# 2019-04-22  22-Apr-19  $2907.97
# 2019-04-18  18-Apr-19  $2905.03
# 2019-04-17  17-Apr-19  $2900.45
# 2019-04-16  16-Apr-19  $2907.06

# %%
sp_returns.drop(columns=['Date'], inplace=True)
sp_returns.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Clean identified numeric fields with $ symbol
sp_returns["Close"] = sp_returns["Close"].str.replace("$", "")
sp_returns["Close"] = sp_returns["Close"].str.replace(",", "")
sp_returns["Close"] = sp_returns["Close"].astype("float")
sp_returns.dtypes
# Out:
# Close    float64
# dtype: object

# %%
sp_returns.columns
# Out:
# Index(['Close'], dtype='object')

# %%
# Rewrite the column names
columns = ["Close"]
sp_returns.columns = columns
sp_returns.head()
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
# Calculate the daily return using the 'pct_change()' function
##note to grader: i know I was supposed to calculate the daily change for SP500 and then merge the files but I kept getting an error so I moved on without it.

sp_returns= sp_returns.pct_change()
sp_returns.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
sp_returns = sp_returns.dropna().copy()
sp_returns
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %%
sp_returns = sp_returns.rename(columns={ "Close": "SP500"})
sp_returns.head()
# Out:
#                SP500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
# Join three datasets

#import pandas as pd
#from pathlib import Path

# Import data
#whale_path = Path("C:\whale_returns.csv")
#algo_path = Path("C:/algo_returns.csv")
#sp_path = Path('c:/sp500_history.csv')

# Read in data and index by date
#whale_returns = pd.read_csv(whale_path, index_col='Date')
#algo_returns = pd.read_csv(algo_path, index_col='Date')
#sp_returns = pd.read_csv(sp_path, index_col='Date')

# %%
# Join by columns axis
joined_data_cols = pd.concat([whale_returns,algo_returns,sp_returns], axis='columns', join='inner')
joined_data_cols.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     SP500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# 2015-03-06 -0.011460 -0.003929
# 2015-03-09  0.001303  0.017254

# %%
sp_returns.head()
# Out:
#                SP500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
joined_data_cols.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     SP500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# 2015-03-06 -0.011460 -0.003929
# 2015-03-09  0.001303  0.017254

# %%
# Section 2. Performance Analysis
# Calculate and plot daily returns of all portfolios.

# Plot a line char of the data after converting and setting the 'Date' column as the datetime index
joined_data_cols.plot(figsize=(20,10), title= "Performance Charts")
# Out:
# <AxesSubplot:title={'center':'Performance Charts'}, xlabel='Date'>

# %%
# Calculate cumulative returns

cumulative_returns = (1 + joined_data_cols).cumprod()
cumulative_returns.plot(figsize=(20,10), title= "Cumulative Charts")
# Out:
# <AxesSubplot:title={'center':'Cumulative Charts'}, xlabel='Date'>

# %%
joined_data_cols.plot.box(figsize=(20,10), title= "Boxplot risk chart")
# Out:
# <AxesSubplot:title={'center':'Boxplot risk chart'}>

# %%
# Daily Standard Deviations
joined_data_cols.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# SP500                          0.008587
# dtype: float64

# %%
sp500_risk = joined_data_cols["SP500"].std()
joined_data_cols.std() > sp500_risk

#Berkshire and Tiger are more risky.
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# SP500                          False
# dtype: bool

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = joined_data_cols.std() * np.sqrt(252)
annualized_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# dtype: float64

# %%
# Plot a rolling 21-day standard deviation of daily returns
joined_data_cols.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Calculate the correlation between each column
correlation = joined_data_cols.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# SP500                                         0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# Algo 2                                          0.507160
# SP500                                          -0.001505
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754157  0.320901  0.826730
# PAULSON & CO.INC.                          0.545451  0.268631  0.678085
# TIGER GLOBAL MANAGEMENT LLC                0.424125  0.164114  0.507160
# BERKSHIRE HATHAWAY INC                     1.000000  0.291678  0.687756
# Algo 1                                     0.291678  1.000000  0.287852
# Algo 2                                     0.687756  0.287852  1.000000
# SP500                                     -0.013856 -0.033963 -0.002192
#
#                                 SP500
# SOROS FUND MANAGEMENT LLC    0.000574
# PAULSON & CO.INC.            0.013549
# TIGER GLOBAL MANAGEMENT LLC -0.001505
# BERKSHIRE HATHAWAY INC      -0.013856
# Algo 1                      -0.033963
# Algo 2                      -0.002192
# SP500                        1.000000

# %%
# Use the `heatmap` function from the Seaborn library to visualize correlations

correlation.style.background_gradient(cmap="summer")
# Out:
# <style  type="text/css" >
# #T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col0,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col1,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row2_col2,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row3_col3,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row4_col4,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row5_col5,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row6_col6{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col1{
#             background-color:  #b2d866;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col2,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row2_col0{
#             background-color:  #8fc766;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col3,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row3_col0{
#             background-color:  #c1e066;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col4{
#             background-color:  #57ab66;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col5,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row5_col0{
#             background-color:  #d3e966;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col6,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row2_col6{
#             background-color:  #088466;
#             color:  #f1f1f1;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col0{
#             background-color:  #b3d966;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col2{
#             background-color:  #6fb766;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col3{
#             background-color:  #8dc666;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col4,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row4_col5{
#             background-color:  #4aa466;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col5{
#             background-color:  #add666;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col6{
#             background-color:  #0b8566;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row2_col1{
#             background-color:  #6db666;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row2_col3{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row2_col4{
#             background-color:  #319866;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row2_col5,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row5_col2{
#             background-color:  #82c066;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row3_col1{
#             background-color:  #8ac466;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row3_col2{
#             background-color:  #6cb666;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row3_col4{
#             background-color:  #50a866;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row3_col5{
#             background-color:  #b0d866;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row3_col6{
#             background-color:  #048266;
#             color:  #f1f1f1;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row4_col0{
#             background-color:  #52a866;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row4_col1{
#             background-color:  #42a066;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row4_col2{
#             background-color:  #2a9466;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row4_col3{
#             background-color:  #4da666;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row4_col6,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row6_col0,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row6_col1,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row6_col2,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row6_col3,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row6_col4,#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row6_col5{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row5_col1{
#             background-color:  #acd666;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row5_col3{
#             background-color:  #b1d866;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row5_col4{
#             background-color:  #4fa766;
#             color:  #000000;
#         }#T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row5_col6{
#             background-color:  #078366;
#             color:  #f1f1f1;
#         }</style><table id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOROS FUND MANAGEMENT LLC</th>        <th class="col_heading level0 col1" >PAULSON & CO.INC. </th>        <th class="col_heading level0 col2" >TIGER GLOBAL MANAGEMENT LLC</th>        <th class="col_heading level0 col3" >BERKSHIRE HATHAWAY INC</th>        <th class="col_heading level0 col4" >Algo 1</th>        <th class="col_heading level0 col5" >Algo 2</th>        <th class="col_heading level0 col6" >SP500</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50level0_row0" class="row_heading level0 row0" >SOROS FUND MANAGEMENT LLC</th>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col1" class="data row0 col1" >0.699823</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col2" class="data row0 col2" >0.561040</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col3" class="data row0 col3" >0.754157</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col4" class="data row0 col4" >0.320901</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col5" class="data row0 col5" >0.826730</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row0_col6" class="data row0 col6" >0.000574</td>
#             </tr>
#             <tr>
#                         <th id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50level0_row1" class="row_heading level0 row1" >PAULSON & CO.INC. </th>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col0" class="data row1 col0" >0.699823</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col2" class="data row1 col2" >0.434308</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col3" class="data row1 col3" >0.545451</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col4" class="data row1 col4" >0.268631</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col5" class="data row1 col5" >0.678085</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row1_col6" class="data row1 col6" >0.013549</td>
#             </tr>
#             <tr>
#                         <th id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50level0_row2" class="row_heading level0 row2" >TIGER GLOBAL MANAGEMENT LLC</th>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row2_col0" class="data row2 col0" >0.561040</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row2_col1" class="data row2 col1" >0.434308</td>
#                         <td id="T_fb96cff6_a530_11eb_9edd_5cc5d4e7da50row2_col2" class="data ro

# %%
# Calculate covariance of all daily returns of berkshire vs. sp500

covariance = joined_data_cols['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(joined_data_cols['SP500'])
covariance
variance = joined_data_cols['SP500'].rolling(60).var()
variance
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-15    0.000041
# 2019-04-16    0.000037
# 2019-04-17    0.000037
# 2019-04-18    0.000037
# 2019-04-22    0.000037
# Name: SP500, Length: 1042, dtype: float64

# %%
# Calculate beta of all daily returns of soros
berk_beta = covariance / variance
berk_beta.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
joined_data_cols.ewm(halflife=21).std().plot(figsize=(20, 10), title="Exponentially Weighted Average")
# Out:
# <AxesSubplot:title={'center':'Exponentially Weighted Average'}, xlabel='Date'>

# %%
# Calculate Sharpe Ratio

sharpe_ratios = (joined_data_cols.mean() * 252) / (joined_data_cols.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# SP500                         -0.518582
# dtype: float64

# %%
sharpe_ratios.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# Final Part: Custom Portfolio

# I donwloaded two files from google docs with google finance, one for apple one for google.

#Step 1 Read DATA
apple_path = Path("C:/aapl_historical.csv")
google_path = Path("C:/goog_historical.csv")

apple = pd.read_csv(apple_path, index_col='Trade DATE', parse_dates=True, infer_datetime_format=True)
google = pd.read_csv(google_path, index_col='Trade DATE', parse_dates=True, infer_datetime_format=True)

apple.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
google =google.sort_index()
apple= apple.sort_index()

# %%
google.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
# Use the concat function to combine the DataFrames by column and perform an inner join. 
combined_df = pd.concat([apple, google], axis="rows", join="inner")

# Display a few rows
combined_df.tail()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-03   GOOG  1185.40
# 2019-05-06   GOOG  1189.39
# 2019-05-07   GOOG  1174.10
# 2019-05-08   GOOG  1166.27
# 2019-05-09   GOOG  1162.38

# %%
combined_df = combined_df.pivot_table(values="NOCP", index="Trade DATE", columns="Symbol")
combined_df.head()
# Out:
# Symbol        AAPL     GOOG
# Trade DATE
# 2018-05-11  188.59  1098.26
# 2018-05-14  188.15  1100.20
# 2018-05-15  186.44  1079.23
# 2018-05-16  188.18  1081.77
# 2018-05-17  186.99  1078.59

# %%
# Use the `pct_change` function to calculate daily returns of closing prices for each column
daily_returns = combined_df.pct_change()
daily_returns.head()


# Use the `dot` function to multiply the weights by each stock's daily return to get the portfolio daily return
weights = [0.5, 0.5]

portfolio_returns = daily_returns.dot(weights)
portfolio_returns.head()

# Use the `plot` function to plot the daily portfolio returns
portfolio_returns.plot()
# Out:
# <AxesSubplot:xlabel='Trade DATE'>

# %%
joined_data_cols["Custom"] = portfolio_returns
joined_data_cols.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-15                     0.000398               -0.010492 -0.004331
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
#
#               Algo 2     SP500    Custom
# Date
# 2019-04-15 -0.004572 -0.000509  0.002231
# 2019-04-16  0.002899  0.002279  0.002519
# 2019-04-17 -0.005228 -0.001577  0.013489
# 2019-04-18 -0.001229 -0.001011  0.001809
# 2019-04-22 -0.001936 -0.008764  0.006686

# %%
#Calculate the Annualized Standard Deviation.
annualized_std = joined_data_cols.std() * np.sqrt(252)
annualized_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# dtype: float64

# %%
# Plot a rolling 21-day standard deviation of daily returns
joined_data_cols.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Calculate and plot the correlation.
correlation = joined_data_cols.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# SP500                                         0.000574            0.013549
# Custom                                        0.698128            0.596216
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# Algo 2                                          0.507160
# SP500                                          -0.001505
# Custom                                          0.340738
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754157  0.320901  0.826730
# PAULSON & CO.INC.                          0.545451  0.268631  0.678085
# TIGER GLOBAL MANAGEMENT LLC                0.424125  0.164114  0.507160
# BERKSHIRE HATHAWAY INC                     1.000000  0.291678  0.687756
# Algo 1                                     0.291678  1.000000  0.287852
# Algo 2                                     0.687756  0.287852  1.000000
# SP500                                     -0.013856 -0.033963 -0.002192
# Custom                                     0.819068  0.267002  0.715360
#
#                                 SP500    Custom
# SOROS FUND MANAGEMENT LLC    0.000574  0.698128
# PAULSON & CO.INC.            0.013549  0.596216
# TIGER GLOBAL MANAGEMENT LLC -0.001505  0.340738
# BERKSHIRE HATHAWAY INC      -0.013856  0.819068
# Algo 1                      -0.033963  0.267002
# Algo 2                      -0.002192  0.715360
# SP500                        1.000000  0.036160
# Custom                       0.036160  1.000000

# %%
# Use the `heatmap` function from the Seaborn library to visualize correlations

correlation.style.background_gradient(cmap="summer")
# Out:
# <style  type="text/css" >
# #T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col0,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row1_col1,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row2_col2,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row3_col3,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row4_col4,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row5_col5,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row6_col6,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row7_col7{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col1,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row7_col0{
#             background-color:  #b2d866;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col2,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row2_col0{
#             background-color:  #8fc766;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col3,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row3_col0{
#             background-color:  #c1e066;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col4,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row7_col2{
#             background-color:  #57ab66;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col5,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row5_col0{
#             background-color:  #d3e966;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col6,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row2_col6{
#             background-color:  #088466;
#             color:  #f1f1f1;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col7{
#             background-color:  #afd766;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row1_col0{
#             background-color:  #b3d966;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row1_col2{
#             background-color:  #6fb766;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row1_col3{
#             background-color:  #8dc666;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row1_col4,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row4_col5,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row7_col4{
#             background-color:  #4aa466;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row1_col5{
#             background-color:  #add666;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row1_col6{
#             background-color:  #0b8566;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row1_col7{
#             background-color:  #94ca66;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row2_col1{
#             background-color:  #6db666;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row2_col3{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row2_col4{
#             background-color:  #319866;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row2_col5,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row5_col2{
#             background-color:  #82c066;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row2_col7,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row3_col4{
#             background-color:  #50a866;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row3_col1{
#             background-color:  #8ac466;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row3_col2{
#             background-color:  #6cb666;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row3_col5{
#             background-color:  #b0d866;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row3_col6{
#             background-color:  #048266;
#             color:  #f1f1f1;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row3_col7{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row4_col0{
#             background-color:  #52a866;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row4_col1{
#             background-color:  #42a066;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row4_col2{
#             background-color:  #2a9466;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row4_col3{
#             background-color:  #4da666;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row4_col6,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row6_col0,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row6_col1,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row6_col2,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row6_col3,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row6_col4,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row6_col5,#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row6_col7{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row4_col7{
#             background-color:  #3d9e66;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row5_col1{
#             background-color:  #acd666;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row5_col3{
#             background-color:  #b1d866;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row5_col4{
#             background-color:  #4fa766;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row5_col6{
#             background-color:  #078366;
#             color:  #f1f1f1;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row5_col7{
#             background-color:  #b4da66;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row7_col1{
#             background-color:  #97cb66;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row7_col3{
#             background-color:  #d2e866;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row7_col5{
#             background-color:  #b7db66;
#             color:  #000000;
#         }#T_37223af6_a534_11eb_aef6_5cc5d4e7da50row7_col6{
#             background-color:  #118866;
#             color:  #000000;
#         }</style><table id="T_37223af6_a534_11eb_aef6_5cc5d4e7da50" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOROS FUND MANAGEMENT LLC</th>        <th class="col_heading level0 col1" >PAULSON & CO.INC. </th>        <th class="col_heading level0 col2" >TIGER GLOBAL MANAGEMENT LLC</th>        <th class="col_heading level0 col3" >BERKSHIRE HATHAWAY INC</th>        <th class="col_heading level0 col4" >Algo 1</th>        <th class="col_heading level0 col5" >Algo 2</th>        <th class="col_heading level0 col6" >SP500</th>        <th class="col_heading level0 col7" >Custom</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_37223af6_a534_11eb_aef6_5cc5d4e7da50level0_row0" class="row_heading level0 row0" >SOROS FUND MANAGEMENT LLC</th>
#                         <td id="T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col1" class="data row0 col1" >0.699823</td>
#                         <td id="T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col2" class="data row0 col2" >0.561040</td>
#                         <td id="T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col3" class="data row0 col3" >0.754157</td>
#                         <td id="T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col4" class="data row0 col4" >0.320901</td>
#                         <td id="T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col5" class="data row0 col5" >0.826730</td>
#                         <td id="T_37223af6_a534_11eb_aef6_5cc5d4e7da50row0_col6" class="data row0 col6" >0.000574</td>

# %%
#Calculate and plot beta for your portfolio compared to the S&P 60 TSX.


covariance = joined_data_cols['Custom'].rolling(window=60).cov(joined_data_cols['SP500'])
covariance
variance = joined_data_cols['Custom'].rolling(60).var()
variance
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-15    0.000150
# 2019-04-16    0.000150
# 2019-04-17    0.000139
# 2019-04-18    0.000139
# 2019-04-22    0.000138
# Name: Custom, Length: 1042, dtype: float64

# %%
# Calculate beta of all daily returns of soros
serra_beta = covariance / variance
serra_beta.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Calculate the Sharpe ratios and generate a bar plot.
# Calculate Sharpe Ratio

sharpe_ratios = (joined_data_cols.mean() * 252) / (joined_data_cols.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# SP500                         -0.518582
# Custom                         0.591039
# dtype: float64

# %%
sharpe_ratios.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
#Algo 1 did the best than Berkshire than mine.
